# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

iris=pd.read_csv("/home/abhishek/Downloads/iris.csv")

iris["species"].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
iris.plot(kind='scatter', x='sepal_length',y='sepal_width');
plt.grid()
plt.show()

# %%
sns.set_style('whitegrid');
sns.FacetGrid(iris,hue='species',height=4)\
.map(plt.scatter, "sepal_length", "sepal_width")\
.add_legend();
plt.show();

# %%
sns.set_style("whitegrid");
sns.pairplot(iris, hue= 'species', height=3)

# %% [markdown]
# # Observations:

# %% [markdown]
# 1. petal_length and petal_width are the most useful features to identify various flower types.
# 2. While Setosa can be easily identified (linearly seperable), Virginica and Versicolor have some overlap.
# 3. We can find "lines" and "if-else" conditions to build a simple model to classify the flower types.

# %%
sns.FacetGrid(iris,hue='species',height=5)\
    .map(sns.distplot,"sepal_length").add_legend();
plt.show()

# %%
iris.petal_length.max()
# Out:
# 6.9

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
import numpy as np



iris_setosa= iris.loc[iris["species"]=="setosa"];
iris_virginica= iris.loc[iris["species"]=="virginica"];
iris_versicolor= iris.loc[iris["species"]=="versicolor"];

plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa['petal_length']));
plt.plot(iris_virginica["petal_length"],np.zeros_like(iris_virginica['petal_length']));
plt.plot(iris_versicolor["petal_length"],np.zeros_like(iris_versicolor["petal_length"]));
plt.show()

# %%
sns.FacetGrid(iris,hue="species",height=5)\
.map(sns.distplot,"petal_length").add_legend();
plt.show()
q=iris_setosa.petal_length.max()
print(q)
# Out:
# 1.9

# %%
counts, bin_edges = np.histogram(iris_setosa["petal_length"], bins=10,density=True);

print(counts)
print(bin_edges,"\n")
pdf = counts/(sum(counts))
print(pdf,"pdf\n")


cdf=np.cumsum(pdf)
print(cdf,"cdf\n")
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

plt.show()
# Out:
# [0.22222222 0.22222222 0.44444444 1.55555556 2.66666667 3.11111111
#  1.55555556 0.88888889 0.         0.44444444]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
#
# [0.02 0.02 0.04 0.14 0.24 0.28 0.14 0.08 0.   0.04] pdf
#
# [0.02 0.04 0.08 0.22 0.46 0.74 0.88 0.96 0.96 1.  ] cdf

# %%
print("Means:")
print(np.mean(iris_setosa["petal_length"]))
#mean with outlier
print(np.mean(np.append(iris_setosa["petal_length"],50)))
print("\nStd-dev:")
print(np.std(iris_setosa["petal_length"]))
# Out:
# Means:
# 1.464
# 2.4156862745098038
#
# Std-dev:
# 0.17176728442867115

# %%
print("\nMedian:")
print(np.median(iris_setosa["petal_length"]))
# with outlier
print(np.median(np.append(iris_setosa["petal_length"],50)))
print("\nQuantiles:")
print(np.percentile(iris_setosa["petal_length"],np.arange(0,101,25)))
# 90th percentile
print("\n90th percentile:")
print(np.percentile(iris_setosa["petal_length"],[90]))

from statsmodels import robust
print("\nMedian standard deviation:")
print(robust.mad(iris_setosa["petal_length"]))
# Out:
# Median:
# 1.5
# 1.5
#
# Quantiles:
# [1.    1.4   1.5   1.575 1.9  ]
#
# 90th percentile:
# [1.7]
#
# Median standard deviation:
# 0.14826022185056031

# %%
sns.boxplot(x='species',y='petal_length',data=iris)
plt.show()

# %%
sns.violinplot(x='species',y='petal_length',data=iris)
plt.show()

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.species.value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64
